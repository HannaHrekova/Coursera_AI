# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product ">
# </a>

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="200" alt="cognitiveclass.ai logo">

# %% [markdown]
# <h1><h1>Pre-trained-Models with PyTorch </h1>

# %% [markdown]
# In this lab, you will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
# <ul>
# <li>change the output layer</li>
# <li> train the model</li>
# <li>  identify  several  misclassified samples</li>
#  </ul>
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
#
# <ul>
#     <li><a href="#download_data"> Download Data</a></li>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#data_class"> Dataset Class</a></li>
#     <li><a href="#Question_1">Question 1</a></li>
#     <li><a href="#Question_2">Question 2</a></li>
#     <li><a href="#Question_3">Question 3</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>120 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Out:
# --2025-01-12 01:33:58--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2598656062 (2.4G) [application/zip]
# Saving to: ‘Positive_tensors.zip’
#
# Positive_tensors.zi 100%[===================>]   2.42G  42.6MB/s    in 60s
#
# 2025-01-12 01:34:58 (41.6 MB/s) - ‘Positive_tensors.zip’ saved [2598656062/2598656062]

# %%
# !unzip -q Positive_tensors.zip

# %%
! wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# !unzip -q Negative_tensors.zip
# Out:
# --2025-01-12 01:38:06--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2111408108 (2.0G) [application/zip]
# Saving to: ‘Negative_tensors.zip’
#
# Negative_tensors.zi 100%[===================>]   1.97G  46.3MB/s    in 45s
#
# 2025-01-12 01:38:52 (44.3 MB/s) - ‘Negative_tensors.zip’ saved [2111408108/2111408108]

# %% [markdown]
# We will install torchvision:

# %%
# !pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.5.1+cu121)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="data_class">Dataset Class</h2>

# %% [markdown]
#  This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
# Create your own dataset object

class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="/home/wsuser/work"
        positive="Positive_tensors"
        negative='Negative_tensors'

        positive_file_path = '/content/Positive_tensors'
        negative_file_path = '/content/Negative_tensors'
        positive_files=[os.path.join(positive_file_path,file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files=[os.path.join(negative_file_path,file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        number_of_samples=len(positive_files)+len(negative_files)
        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0

        if train:
            self.all_files=self.all_files[0:30000]
            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:
            self.all_files=self.all_files[30000:]
            self.Y=self.Y[30000:]
            self.len=len(self.all_files)

    # Get the length
    def __len__(self):
        return self.len

    # Getter
    def __getitem__(self, idx):

        image=torch.load(self.all_files[idx], weights_only=True)
        y=self.Y[idx]

        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y

print("done")
# Out:
# done

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
model = models.resnet18(pretrained=True)

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
model.fc = nn.Linear(in_features=512, out_features=2)

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# <h2 id="Question_2">Question 2: Train the Model</h2>

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
criterion = torch.nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)

train_loader = DataLoader(dataset=train_dataset, batch_size=100, shuffle=True)
validation_loader = DataLoader(dataset=validation_dataset, batch_size=100, shuffle=False)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
optimizer = torch.optim.Adam([parameters for parameters in model.parameters() if parameters.requires_grad],lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

n_epochs = 1
loss_list = []
accuracy_list = []
accuracy = 0
correct = 0
N_test = len(validation_dataset)
N_train = len(train_dataset)
start_time = time.time()

batch_size = 100

running_loss = 0

model.to(device)

for epoch in range(n_epochs):
    for i, (x, y) in enumerate(train_loader):
        print('-' * 30)
        print('Iteration (train phase) {}/{}'.format(i+1, int(N_train/batch_size)))
        i_start_time = time.time()

        x = x.to(device)
        y = y.to(device, dtype=torch.long)

        model.train()

        optimizer.zero_grad()

        yhat = model(x)

        loss = criterion(yhat, y)

        loss.backward()

        optimizer.step()

        loss_list.append(loss.item())
        print("Finished in {} (s)".format(time.time()-i_start_time))

    correct = 0
    for i, (x_test, y_test) in enumerate(validation_loader):
        print('-' * 30)
        print('Iteration (validation phase) {}/{}'.format(i+1, int(N_test/batch_size)))
        i_start_time = time.time()

        x_test = x_test.to(device)
        y_test = y_test.to(device)

        model.eval()

        yhat = model(x_test)

        _, yhat = torch.max(yhat.data, 1)

        correct += (yhat == y_test).sum().item()

        print("Finished in {} (s)".format(time.time()-i_start_time))

    accuracy = correct / N_test
    print("Epoch %d - accuracy: %.3f" % (epoch+1, accuracy))
    accuracy_list.append(accuracy)
    print("-" * 72)

    print("Finished epoch {} in {} (s).".format(epoch+1, time.time()-start_time))
# Out:
# ------------------------------
# Iteration (train phase) 1/300
# Finished in 13.056902170181274 (s)
# ------------------------------
# Iteration (train phase) 2/300
# Finished in 14.136969566345215 (s)
# ------------------------------
# Iteration (train phase) 3/300
# Finished in 15.646460056304932 (s)
# ------------------------------
# Iteration (train phase) 4/300
# Finished in 11.639911413192749 (s)
# ------------------------------
# Iteration (train phase) 5/300
# Finished in 16.814853191375732 (s)
# ------------------------------
# Iteration (train phase) 6/300
# Finished in 12.507556676864624 (s)
# ------------------------------
# Iteration (train phase) 7/300
# Finished in 14.869935035705566 (s)
# ------------------------------
# Iteration (train phase) 8/300
# Finished in 15.533624172210693 (s)
# ------------------------------
# Iteration (train phase) 9/300
# Finished in 11.89081859588623 (s)
# ------------------------------
# Iteration (train phase) 10/300
# Finished in 16.919702768325806 (s)
# ------------------------------
# Iteration (train phase) 11/300
# Finished in 12.279685735702515 (s)
# ------------------------------
# Iteration (train phase) 12/300
# Finished in 14.771573305130005 (s)
# ------------------------------
# Iteration (train phase) 13/300
# Finished in 25.127987384796143 (s)
# ------------------------------
# Iteration (train phase) 14/300
# Finished in 13.141831874847412 (s)
# ------------------------------
# Iteration (train phase) 15/300
# Finished in 14.906955480575562 (s)
# ------------------------------
# Iteration (train phase) 16/300
# Finished in 16.166598320007324 (s)
# ------------------------------
# Iteration (train phase) 17/300
# Finished in 11.676230669021606 (s)
# ------------------------------
# Iteration (train phase) 18/300
# Finished in 16.468598127365112 (s)
# ------------------------------
# Iteration (train phase) 19/300
# Finished in 13.828736305236816 (s)
# ------------------------------
# Iteration (train phase) 20/300
# Finished in 13.645334720611572 (s)
# ------------------------------
# Iteration (train phase) 21/300
# Finished in 16.765154361724854 (s)
# ------------------------------
# Iteration (train phase) 22/300
# Finished in 11.277631282806396 (s)
# ------------------------------
# Iteration (train phase) 23/300
# Finished in 15.940637350082397 (s)
# ------------------------------
# Iteration (train phase) 24/300
# Finished in 14.095997333526611 (s)
# ------------------------------
# Iteration (train phase) 25/300
# Finished in 13.097397804260254 (s)
# ------------------------------
# Iteration (train phase) 26/300
# Finished in 17.52792525291443 (s)
# ------------------------------
# Iteration (train phase) 27/300
# Finished in 11.596824645996094 (s)
# ------------------------------
# Iteration (train phase) 28/300
# Finished in 15.147701740264893 (s)
# ------------------------------
# Iteration (train phase) 29/300
# Finished in 14.626991033554077 (s)
# ------------------------------
# Iteration (train phase) 30/300
# Finished in 12.388241291046143 (s)
# ------------------------------
# Iteration (train phase) 31/300
# Finished in 17.121933698654175 (s)
# ------------------------------
# Iteration (train phase) 32/300
# Finished in 11.15126633644104 (s)
# ------------------------------
# Iteration (train phase) 33/300
# Finished in 15.362824201583862 (s)
# ------------------------------
# Iteration (train phase) 34/300
# Finished in 14.231492042541504 (s)
# ------------------------------
# Iteration (train phase) 35/300
# Finished in 12.651382207870483 (s)
# ------------------------------
# Iteration (train phase) 36/300
# Finished in 17.257604598999023 (s)
# ------------------------------
# Iteration (train phase) 37/300
# Finished in 11.561913013458252 (s)
# ------------------------------
# Iteration (train phase) 38/300
# Finished in 15.45492935180664 (s)
# ------------------------------
# Iteration (train phase) 39/300
# Finished in 14.85964059829712 (s)
# ------------------------------
# Iteration (train phase) 40/300
# Finished in 12.456753730773926 (s)
# ------------------------------
# Iteration (train phase) 41/300
# Finished in 17.836657285690308 (s)
# ------------------------------
# Iteration (train phase) 42/300
# Finished in 16.79831600189209 (s)
# ------------------------------
# Iteration (train phase) 43/300
# Finished in 12.797244310379028 (s)
# ------------------------------
# Iteration (train phase) 44/300
# Finished in 17.238849639892578 (s)
# ------------------------------
# Iteration (train phase) 45/300
# Finished in 11.669875621795654 (s)
# ------------------------------
# Iteration (train phase) 46/300
# Finished in 15.386401414871216 (s)
# ------------------------------
# Iteration (train phase) 47/300
# Finished in 14.771849393844604 (s)
# ------------------------------
# Iteration (train phase) 48/300
# Finished in 12.4909029006958 (s)
# ------------------------------
# Iteration (train phase) 49/300
# Finished in 17.256075382232666 (s)
# ------------------------------
# Iteration (train phase) 50/300
# Finished in 11.604114294052124 (s)
# ------------------------------
# Iteration (train phase) 51/300
# Finished in 15.31662654876709 (s)
# ------------------------------
# Iteration (train phase) 52/300
# Finished in 22.416597604751587 (s)
# ------------------------------
# Iteration (train phase) 53/300
# Finished in 13.479570627212524 (s)
# ------------------------------
# Iteration (train phase) 54/300
# Finished in 17.19829773902893 (s)
# ------------------------------
# Iteration (train phase) 55/300
# Finished in 13.010077714920044 (s)
# ------------------------------
# Iteration (train phase) 56/300
# Finished in 14.539313077926636 (s)
# ------------------------------
# Iteration (train phase) 57/300
# Finished in 16.27865743637085 (s)
# ------------------------------
# Iteration (train phase) 58/300
# Finished in 11.417052745819092 (s)
# ------------------------------
# Iteration (train phase) 59/300
# Finished in 16.291563749313354 (s)
# ------------------------------
# Iteration (train phase) 60/300
# Finished in 13.806506156921387 (s)
# ------------------------------
# Iteration (train phase) 61/300
# Finished in 13.766948699951172 (s)
# ------------------------------
# Iteration (train phase) 62/300
# Finished in 17.04965853691101 (s)
# ------------------------------
# Iteration (train phase) 63/300
# Finished in 11.0570547580719 (s)
# ------------------------------
# Iteration (train phase) 64/300
# Finished in 16.15604567527771 (s)
# ------------------------------
# Iteration (train phase) 65/300
# Finished in 13.908967018127441 (s)
# ------------------------------
# Iteration (train phase) 66/300
# Finished in 13.23540449142456 (s)
# ------------------------------
# Iteration (train phase) 67/300
# Finished in 16.83911943435669 (s)
# ------------------------------
# Iteration (train phase) 68/300
# Finished in 11.118721008300781 (s)
# ------------------------------
# Iteration (train phase) 69/300
# Finished in 15.87585735321045 (s)
# ------------------------------
# Iteration (train phase) 70/300
# Finished in 13.846835136413574 (s)
# ------------------------------
# Iteration (train phase) 71/300
# Finished in 13.249948024749756 (s)
# ------------------------------
# Iteration (train phase) 72/300
# Finished in 16.652690887451172 (s)
# ------------------------------
# Iteration (train phase) 73/300
# Finished in 10.963559627532959 (s)
# ------------------------------
# Iteration (train phase) 74/300
# Finished in 15.935638904571533 (s)
# ------------------------------
# Iteration (train phase) 75/300
# Finished in 13.746570587158203 (s)
# ------------------------------
# Iteration (train phase) 76/300
# Finished in 13.497326374053955 (s)
# ------------------------------
# Iteration (train phase) 77/300
# Finished in 16.576200485229492 (s)
# ------------------------------
# Iteration (train phase) 78/300
# Finished in 11.273755550384521 (s)
# ------------------------------
# Iteration (train phase) 79/300
# Finished in 16.20029592514038 (s)
# ------------------------------
# Iteration (train phase) 80/300
# Finished in 13.876445770263672 (s)
# ------------------------------
# Iteration (train phase) 81/300
# Finished in 13.707964658737183 (s)
# ------------------------------
# Iteration (train phase) 82/300
# Finished in 16.983427047729492 (s)
# ------------------------------
# Iteration (train phase) 83/300
# Finished in 11.261096000671387 (s)
# ------------------------------
# Iteration (train phase) 84/300
# Finished in 15.947728872299194 (s)
# ------------------------------
# Iteration (train phase) 85/300
# Finished in 14.073567628860474 (s)
# ------------------------------
# Iteration (train phase) 86/300
# Finished in 13.325639486312866 (s)
# ------------------------------
# Iteration (train phase) 87/300
# Finished in 16.934229135513306 (s)
# ------------------------------
# Iteration (train phase) 88/300
# Finished in 11.294044733047485 (s)
# ------------------------------
# Iteration (train phase) 89/300
# Finished in 16.164112091064453 (s)
# ------------------------------
# Iteration (train phase) 90/300
# Finished in 13.794106483459473 (s)
# ------------------------------
# Iteration (train phase) 91/300
# Finished in 13.321858406066895 (s)
# ------------------------------
# Iteration (train phase) 92/300
# Finished in 24.456398487091064 (s)
# ------------------------------
# Iteration (train phase) 93/300
# Finished in 12.119671821594238 (s)
# ------------------------------
# Iteration (train phase) 94/300
# Finished in 15.722984790802002 (s)
# ------------------------------
# Iteration (train phase) 95/300
# Finished in 14.972782611846924 (s)
# ------------------------------
# Iteration (train phase) 96/300
# Finished in 12.501097917556763 (s)
# ------------------------------
# Iteration (train phase) 97/300
# Finished in 17.27681612968445 (s)
# ------------------------------
# Iteration (train phase) 98/300
# Finished in 12.098467826843262 (s)
# ------------------------------
# Iteration (train phase) 99/300
# Finished in 15.039498329162598 (s)
# ------------------------------
# Iteration (train phase) 100/300
# Finished in 15.281988859176636 (s)
# ------------------------------
# Iteration (train phase) 101/300
# Finished in 12.251256704330444 (s)
# ------------------------------
# Iteration (train phase) 102/300
# Finished in 17.450101375579834 (s)
# ------------------------------
# Iteration (train phase) 103/300
# Finished in 11.88225769996643 (s)
# ------------------------------
# Iteration (train phase) 104/300
# Finished in 15.09442138671875 (s)
# ------------------------------
# Iteration (train phase) 105/300
# Finished in 15.026505470275879 (s)
# ------------------------------
# Iteration (train phase) 106/300
# Finished in 12.04732060432434 (s)
# ------------------------------
# Iteration (train phase) 107/300
# Finished in 17.06977081298828 (s)
# ------------------------------
# Iteration (train phase) 108/300
# Finished in 11.871524572372437 (s)
# ------------------------------
# Iteration (train phase) 109/300
# Finished in 14.88549017906189 (s)
# ------------------------------
# Iteration (train phase) 110/300
# Finished in 14.866743326187134 (s)
# ------------------------------
# Iteration (train phase) 111/300
# Finished in 12.072025060653687 (s)
# ------------------------------
# Iteration (train phase) 112/300
# Finished in 16.998507261276245 (s)
# ------------------------------
# Iteration (train phase) 113/300
# Finished in 12.371463298797607 (s)
# ------------------------------
# Iteration (train phase) 114/300
# Finished in 14.829766035079956 (s)
# ------------------------------
# Iteration (train phase) 115/300
# Finished in 15.351394891738892 (s)
# ------------------------------
# Iteration (train phase) 116/300
# Finished in 11.933181285858154 (s)
# ------------------------------
# Iteration (train phase) 117/300
# Finished in 16.912100791931152 (s)
# ------------------------------
# Iteration (train phase) 118/300
# Finished in 12.448554992675781 (s)
# ------------------------------
# Iteration (train phase) 119/300
# Finished in 14.42020034790039 (s)
# ------------------------------
# Iteration (train phase) 120/300
# Finished in 15.77502989768982 (s)
# ------------------------------
# Iteration (train phase) 121/300
# Finished in 11.71237301826477 (s)
# ------------------------------
# Iteration (train phase) 122/300
# Finished in 16.990083694458008 (s)
# ------------------------------
# Iteration (train phase) 123/300
# Finished in 13.157426357269287 (s)
# ------------------------------
# Iteration (train phase) 124/300
# Finished in 14.255348443984985 (s)
# ------------------------------
# Iteration (train phase) 125/300
# Finished in 16.325162410736084 (s)
# ------------------------------
# Iteration (train phase) 126/300
# Finished in 11.375473976135254 (s)
# ------------------------------
# Iteration (train phase) 127/300
# Finished in 16.388017416000366 (s)
# ------------------------------
# Iteration (train phase) 128/300
# Finished in 13.553167819976807 (s)
# ------------------------------
# Iteration (train phase) 129/300
# Finished in 13.583220720291138 (s)
# ------------------------------
# Iteration (train phase) 130/300
# Finished in 16.647839069366455 (s)
# ------------------------------
# Iteration (train phase) 131/300
# Finished in 10.996264696121216 (s)
# ------------------------------
# Iteration (train phase) 132/300
# Finished in 23.767561674118042 (s)
# ------------------------------
# Iteration (train phase) 133/300
# Finished in 15.145870208740234 (s)
# ------------------------------
# Iteration (train phase) 134/300
# Finished in 12.873075008392334 (s)
# ------------------------------
# Iteration (train phase) 135/300
# Finished in 17.197959899902344 (s)
# ------------------------------
# Iteration (train phase) 136/300
# Finished in 12.136616230010986 (s)
# ------------------------------
# Iteration (train phase) 137/300
# Finished in 14.817924976348877 (s)
# ------------------------------
# Iteration (train phase) 138/300
# Finished in 15.306025743484497 (s)
# ------------------------------
# Iteration (train phase) 139/300
# Finished in 11.895725727081299 (s)
# ------------------------------
# Iteration (train phase) 140/300
# Finished in 16.833781480789185 (s)
# ------------------------------
# Iteration (train phase) 141/300
# Finished in 12.397122383117676 (s)
# ------------------------------
# Iteration (train phase) 142/300
# Finished in 14.350213766098022 (s)
# ------------------------------
# Iteration (train phase) 143/300
# Finished in 15.260051727294922 (s)
# ------------------------------
# Iteration (train phase) 144/300
# Finished in 11.573451519012451 (s)
# ------------------------------
# Iteration (train phase) 145/300
# Finished in 16.933717012405396 (s)
# ------------------------------
# Iteration (train phase) 146/300
# Finished in 12.188827276229858 (s)
# ------------------------------
# Iteration (train phase) 147/300
# Finished in 14.573236465454102 (s)
# ------------------------------
# Iteration (train phase) 148/300
# Finished in 15.166808843612671 (s)
# ------------------------------
# Iteration (train phase) 149/300
# Finished in 11.840678215026855 (s)
# ------------------------------
# Iteration (train phase) 150/300
# Finished in 16.61461877822876 (s)
# ------------------------------
# Iteration (train phase) 151/300
# Finished in 12.291618585586548 (s)
# ------------------------------
# Iteration (train phase) 152/300
# Finished in 14.371078968048096 (s)
# ------------------------------
# Iteration (train phase) 153/300
# Finished in 15.81199598312378 (s)
# ------------------------------
# Iteration (train phase) 154/300
# Finished in 11.568833827972412 (s)
# ------------------------------
# Iteration (train phase) 155/300
# Finished in 16.852617025375366 (s)
# ------------------------------
# Iteration (train phase) 156/300
# Finished in 13.087472200393677 (s)
# ------------------------------
# Iteration (train phase) 157/300
# Finished in 14.04886531829834 (s)
# ------------------------------
# Iteration (train phase) 158/300
# Finished in 16.223684072494507 (s)
# ------------------------------
# Iteration (train phase) 159/300
# Finished in 11.1714448928833 (s)
# ------------------------------
# Iteration (train phase) 160/300
# Finished in 16.168229579925537 (s)
# ------------------------------
# Iteration (train phase) 161/300
# Finished in 14.126296043395996 (s)
# ------------------------------
# Iteration (train phase) 162/300
# Finished in 13.029426336288452 (s)
# ------------------------------
# Iteration (train phase) 163/300
# Finished in 17.249233961105347 (s)
# ------------------------------
# Iteration (train phase) 164/300
# Finished in 11.650964498519897 (s)
# ------------------------------
# Iteration (train phase) 165/300
# Finished in 15.271431684494019 (s)
# ------------------------------
# Iteration (train phase) 166/300
# Finished in 15.05096173286438 (s)
# ------------------------------
# Iteration (train phase) 167/300
# Finished in 12.911699771881104 (s)
# ------------------------------
# Iteration (train phase) 168/300
# Finished in 16.820926427841187 (s)
# ------------------------------
# Iteration (train phase) 169/300
# Finished in 12.597229957580566 (s)
# ------------------------------
# Iteration (train phase) 170/300
# Finished in 14.432116508483887 (s)
# ------------------------------
# Iteration (train phase) 171/300
# Finished in 15.998307943344116 (s)
# ------------------------------
# Iteration (train phase) 172/300
# Finished in 20.73072910308838 (s)
# ------------------------------
# Iteration (train phase) 173/300
# Finished in 16.081607341766357 (s)
# ------------------------------
# Iteration (train phase) 174/300
# Finished in 16.061814069747925 (s)
# ------------------------------
# Iteration (train phase) 175/300
# Finished in 11.926895380020142 (s)
# ------------------------------
# Iteration (train phase) 176/300
# Finished in 17.024362802505493 (s)
# ------------------------------
# Iteration (train phase) 177/300
# Finished in 13.580802202224731 (s)
# ------------------------------
# Iteration (train phase) 178/300
# Finished in 14.00324010848999 (s)
# ------------------------------
# Iteration (train phase) 179/300
# Finished in 16.947831630706787 (s)
# ------------------------------
# Iteration (train phase) 180/300
# Finished in 11.441105842590332 (s)
# ------------------------------
# Iteration (train phase) 181/300
# Finished in 16.141024589538574 (s)
# ------------------------------
# Iteration (train phase) 182/300
# Finished in 14.675474882125854 (s)
# ------------------------------
# Iteration (train phase) 183/300
# Finished in 13.027482509613037 (s)
# ------------------------------
# Iteration (train phase) 184/300
# Finished in 17.47639560699463 (s)
# ------------------------------
# Iteration (train phase) 185/300
# Finished in 11.533450365066528 (s)
# ------------------------------
# Iteration (train phase) 186/300
# Finished in 15.86979055404663 (s)
# ------------------------------
# Iteration (train phase) 187/300
# Finished in 15.103689193725586 (s)
# ------------------------------
# Iteration (train phase) 188/300
# Finished in 12.331624984741211 (s)
# ------------------------------
# Iteration (train phase) 189/300
# Finished in 17.06428360939026 (s)
# ------------------------------
# Iteration (train phase) 190/300
# Finished in 11.748927116394043 (s)
# ------------------------------
# Iteration (train phase) 191/300
# Finished in 15.250592231750488 (s)
# ------------------------------
# Iteration (train phase) 192/300
# Finished in 15.336335182189941 (s)
# ------------------------------
# Iteration (train phase) 193/300
# Finished in 12.08144235610962 (s)
# ------------------------------
# Iteration (train phase) 194/300
# Finished in 17.314640760421753 (s)
# ------------------------------
# Iteration (train phase) 195/300
# Finished in 12.935749292373657 (s)
# ------------------------------
# Iteration (train phase) 196/300
# Finished in 14.525726079940796 (s)
# ------------------------------
# Iteration (train phase) 197/300
# Finished in 16.330687522888184 (s)
# ------------------------------
# Iteration (train phase) 198/300
# Finished in 11.758849382400513 (s)
# ------------------------------
# Iteration (train phase) 199/300
# Finished in 16.958813428878784 (s)
# ------------------------------
# Iteration (train phase) 200/300
# Finished in 14.257355451583862 (s)
# ------------------------------
# Iteration (train phase) 201/300
# Finished in 14.795458555221558 (s)
# ------------------------------
# Iteration (train phase) 202/300
# Finished in 17.58578085899353 (s)
# ------------------------------
# Iteration (train phase) 203/300
# Finished in 11.431061029434204 (s)
# ------------------------------
# Iteration (train phase) 204/300
# Finished in 15.773266315460205 (s)
# ------------------------------
# Iteration (train phase) 205/300
# Finished in 15.114026546478271 (s)
# ------------------------------
# Iteration (train phase) 206/300
# Finished in 12.463984966278076 (s)
# ------------------------------
# Iteration (train phase) 207/300
# Finished in 17.310554027557373 (s)
# ------------------------------
# Iteration (train phase) 208/300
# Finished in 12.273949146270752 (s)
# ------------------------------
# Iteration (train phase) 209/300
# Finished in 15.216357707977295 (s)
# ------------------------------
# Iteration (train phase) 210/300
# Finished in 15.643951892852783 (s)
# ------------------------------
# Iteration (train phase) 211/300
# Finished in 19.895718812942505 (s)
# ------------------------------
# Iteration (train phase) 212/300
# Finished in 17.178611755371094 (s)
# ------------------------------
# Iteration (train phase) 213/300
# Finished in 14.414076328277588 (s)
# ------------------------------
# Iteration (train phase) 214/300
# Finished in 13.179473876953125 (s)
# ------------------------------
# Iteration (train phase) 215/300
# Finished in 17.227438926696777 (s)
# ------------------------------
# Iteration (train phase) 216/300
# Finished in 12.069601058959961 (s)
# ------------------------------
# Iteration (train phase) 217/300
# Finished in 15.123862028121948 (s)
# ------------------------------
# Iteration (train phase) 218/300
# Finished in 15.602209568023682 (s)
# ------------------------------
# Iteration (train phase) 219/300
# Finished in 11.984513282775879 (s)
# ------------------------------
# Iteration (train phase) 220/300
# Finished in 17.161134958267212 (s)
# ------------------------------
# Iteration (train phase) 221/300
# Finished in 12.572951316833496 (s)
# ------------------------------
# Iteration (train phase) 222/300
# Finished in 14.608509540557861 (s)
# ------------------------------
# Iteration (train phase) 223/300
# Finished in 15.684000492095947 (s)
# ------------------------------
# Iteration (train phase) 224/300
# Finished in 11.634872913360596 (s)
# ------------------------------
# Iteration (train phase) 225/300
# Finished in 16.79643678665161 (s)
# ------------------------------
# Iteration (train phase) 226/300
# Finished in 12.82690715789795 (s)
# ------------------------------
# Iteration (train phase) 227/300
# Finished in 14.147258281707764 (s)
# ------------------------------
# Iteration (train phase) 228/300
# Finished in 17.218348264694214 (s)
# ------------------------------
# Iteration (train phase) 229/300
# Finished in 11.519628763198853 (s)
# ------------------------------
# Iteration (train phase) 230/300
# Finished in 16.780758142471313 (s)
# ------------------------------
# Iteration (train phase) 231/300
# Finished in 12.961716175079346 (s)
# ------------------------------
# Iteration (train phase) 232/300
# Finished in 14.365467309951782 (s)
# ------------------------------
# Iteration (train phase) 233/300
# Finished in 16.578534603118896 (s)
# ------------------------------
# Iteration (train phase) 234/300
# Finished in 11.570229291915894 (s)
# ------------------------------
# Iteration (train phase) 235/300
# Finished in 16.192456483840942 (s)
# ------------------------------
# Iteration (train phase) 236/300
# Finished in 14.360913515090942 (s)
# ------------------------------
# Iteration (train phase) 237/300
# Finished in 13.151160478591919 (s)
# ------------------------------
# Iteration (train phase) 238/300
# Finished in 17.348421335220337 (s)
# ------------------------------
# Iteration (train phase) 239/300
# Finished in 11.705837488174438 (s)
# ------------------------------
# Iteration (train phase) 240/300
# Finished in 15.632703304290771 (s)
# ------------------------------
# Iteration (train phase) 241/300
# Finished in 15.287405490875244 (s)
# ------------------------------
# Iteration (train phase) 242/300
# Finished in 12.373913764953613 (s)
# ------------------------------
# Iteration (train phase) 243/300
# Finished in 17.11659049987793 (s)
# ------------------------------
# Iteration (train phase) 244/300
# Finished in 12.92097806930542 (s)
# ------------------------------
# Iteration (train phase) 245/300
# Finished in 14.56214952468872 (s)
# ------------------------------
# Iteration (train phase) 246/300
# Finished in 16.287512063980103 (s)
# ------------------------------
# Iteration (train phase) 247/300
# Finished in 11.566182374954224 (s)
# ------------------------------
# Iteration (train phase) 248/300
# Finished in 16.419950246810913 (s)
# ------------------------------
# Iteration (train phase) 249/300
# Finished in 13.853942632675171 (s)
# ------------------------------
# Iteration (train phase) 250/300
# Finished in 21.252843141555786 (s)
# ------------------------------
# Iteration (train phase) 251/300
# Finished in 15.98503589630127 (s)
# ------------------------------
# Iteration (train phase) 252/300
# Finished in 15.651142120361328 (s)
# ------------------------------
# Iteration (train phase) 253/300
# Finished in 11.769803285598755 (s)
# ------------------------------
# Iteration (train phase) 254/300
# Finished in 16.887381315231323 (s)
# ------------------------------
# Iteration (train phase) 255/300
# Finished in 13.384594202041626 (s)
# ------------------------------
# Iteration (train phase) 256/300
# Finished in 14.025730609893799 (s)
# ------------------------------
# Iteration (train phase) 257/300
# Finished in 16.682848930358887 (s)
# ------------------------------
# Iteration (train phase) 258/300
# Finished in 11.172611713409424 (s)
# ------------------------------
# Iteration (train phase) 259/300
# Finished in 16.078895807266235 (s)
# ------------------------------
# Iteration (train phase) 260/300
# Finished in 14.286758422851562 (s)
# ------------------------------
# Iteration (train phase) 261/300
# Finished in 13.116270780563354 (s)
# ------------------------------
# Iteration (train phase) 262/300
# Finished in 17.401816606521606 (s)
# ------------------------------
# Iteration (train phase) 263/300
# Finished in 11.585184574127197 (s)
# ------------------------------
# Iteration (train phase) 264/300
# Finished in 15.52440595626831 (s)
# ------------------------------
# Iteration (train phase) 265/300
# Finished in 14.859895944595337 (s)
# ------------------------------
# Iteration (train phase) 266/300
# Finished in 12.137933492660522 (s)
# ------------------------------
# Iteration (train phase) 267/300
# Finished in 17.033324241638184 (s)
# ------------------------------
# Iteration (train phase) 268/300
# Finished in 11.91744089126587 (s)
# ------------------------------
# Iteration (train phase) 269/300
# Finished in 15.073636293411255 (s)
# ------------------------------
# Iteration (train phase) 270/300
# Finished in 15.437534809112549 (s)
# ------------------------------
# Iteration (train phase) 271/300
# Finished in 12.220338821411133 (s)
# ------------------------------
# Iteration (train phase) 272/300
# Finished in 17.016242265701294 (s)
# ------------------------------
# Iteration (train phase) 273/300
# Finished in 13.232480525970459 (s)
# ------------------------------
# Iteration (train phase) 274/300
# Finished in 13.88132619857788 (s)
# ------------------------------
# Iteration (train phase) 275/300
# Finished in 17.346243858337402 (s)
# ------------------------------
# Iteration (train phase) 276/300
# Finished in 11.291200399398804 (s)
# ------------------------------
# Iteration (train phase) 277/300
# Finished in 16.373006343841553 (s)
# ------------------------------
# Iteration (train phase) 278/300
# Finished in 13.732422113418579 (s)
# ------------------------------
# Iteration (train phase) 279/300
# Finished in 13.739717721939087 (s)
# ------------------------------
# Iteration (train phase) 280/300
# Finished in 17.042121648788452 (s)
# ------------------------------
# Iteration (train phase) 281/300
# Finished in 11.37946891784668 (s)
# ------------------------------
# Iteration (train phase) 282/300
# Finished in 15.634582042694092 (s)
# ------------------------------
# Iteration (train phase) 283/300
# Finished in 14.98762845993042 (s)
# ------------------------------
# Iteration (train phase) 284/300
# Finished in 12.296963453292847 (s)
# ------------------------------
# Iteration (train phase) 285/300
# Finished in 17.051316022872925 (s)
# ------------------------------
# Iteration (train phase) 286/300
# Finished in 12.510376930236816 (s)
# ------------------------------
# Iteration (train phase) 287/300
# Finished in 14.96252989768982 (s)
# ------------------------------
# Iteration (train phase) 288/300
# Finished in 16.88714361190796 (s)
# ------------------------------
# Iteration (train phase) 289/300
# Finished in 19.682358503341675 (s)
# ------------------------------
# Iteration (train phase) 290/300
# Finished in 16.076282024383545 (s)
# ------------------------------
# Iteration (train phase) 291/300
# Finished in 15.795148134231567 (s)
# ------------------------------
# Iteration (train phase) 292/300
# Finished in 11.77644944190979 (s)
# ------------------------------
# Iteration (train phase) 293/300
# Finished in 16.81274700164795 (s)
# ------------------------------
# Iteration (train phase) 294/300
# Finished in 13.334211349487305 (s)
# ------------------------------
# Iteration (train phase) 295/300
# Finished in 13.91926097869873 (s)
# ------------------------------
# Iteration (train phase) 296/300
# Finished in 16.564872980117798 (s)
# ------------------------------
# Iteration (train phase) 297/300
# Finished in 11.035140752792358 (s)
# ------------------------------
# Iteration (train phase) 298/300
# Finished in 16.118699550628662 (s)
# ------------------------------
# Iteration (train phase) 299/300
# Finished in 13.90227222442627 (s)
# ------------------------------
# Iteration (train phase) 300/300
# Finished in 13.262114763259888 (s)
# ------------------------------
# Iteration (validation phase) 1/100
# Finished in 15.843821048736572 (s)
# ------------------------------
# Iteration (validation phase) 2/100
# Finished in 10.37497067451477 (s)
# ------------------------------
# Iteration (validation phase) 3/100
# Finished in 16.131731748580933 (s)
# ------------------------------
# Iteration (validation phase) 4/100
# Finished in 11.063928842544556 (s)
# ------------------------------
# Iteration (validation phase) 5/100
# Finished in 14.26386046409607 (s)
# ------------------------------
# Iteration (validation phase) 6/100
# Finished in 13.179073095321655 (s)
# ------------------------------
# Iteration (validation phase) 7/100
# Finished in 12.421987295150757 (s)
# ------------------------------
# Iteration (validation phase) 8/100
# Finished in 15.556811332702637 (s)
# ------------------------------
# Iteration (validation phase) 9/100
# Finished in 10.854177713394165 (s)
# ------------------------------
# Iteration (validation phase) 10/100
# Finished in 16.502461194992065 (s)
# ------------------------------
# Iteration (validation phase) 11/100
# Finished in 11.413198471069336 (s)
# ------------------------------
# Iteration (validation phase) 12/100
# Finished in 14.384052515029907 (s)
# ------------------------------
# Iteration (validation phase) 13/100
# Finished in 13.62587857246399 (s)
# ------------------------------
# Iteration (validation phase) 14/100
# Finished in 12.25990343093872 (s)
# ------------------------------
# Iteration (validation phase) 15/100
# Finished in 16.01642394065857 (s)
# ------------------------------
# Iteration (validation phase) 16/100
# Finished in 10.04721713066101 (s)
# ------------------------------
# Iteration (validation phase) 17/100
# Finished in 15.988122463226318 (s)
# ------------------------------
# Iteration (validation phase) 18/100
# Finished in 11.640369176864624 (s)
# ------------------------------
# Iteration (validation phase) 19/100
# Finished in 14.246334791183472 (s)
# ------------------------------
# Iteration (validation phase) 20/100
# Finished in 14.12671446800232 (s)
# ------------------------------
# Iteration (validation phase) 21/100
# Finished in 11.91640019416809 (s)
# ------------------------------
# Iteration (validation phase) 22/100
# Finished in 16.125043392181396 (s)
# ------------------------------
# Iteration (validation phase) 23/100
# Finished in 10.844507694244385 (s)
# ------------------------------
# Iteration (validation phase) 24/100
# Finished in 15.370010137557983 (s)
# ------------------------------
# Iteration (validation phase) 25/100
# Finished in 12.396857261657715 (s)
# ------------------------------
# Iteration (validation phase) 26/100
# Finished in 13.253445625305176 (s)
# ------------------------------
# Iteration (validation phase) 27/100
# Finished in 14.386619567871094 (s)
# ------------------------------
# Iteration (validation phase) 28/100
# Finished in 11.217754125595093 (s)
# ------------------------------
# Iteration (validation phase) 29/100
# Finished in 16.620619297027588 (s)
# ------------------------------
# Iteration (validation phase) 30/100
# Finished in 10.2867112159729 (s)
# ------------------------------
# Iteration (validation phase) 31/100
# Finished in 22.7319073677063 (s)
# ------------------------------
# Iteration (validation phase) 32/100
# Finished in 13.377447366714478 (s)
# ------------------------------
# Iteration (validation phase) 33/100
# Finished in 12.859486103057861 (s)
# ------------------------------
# Iteration (validation phase) 34/100
# Finished in 15.35092043876648 (s)
# ------------------------------
# Iteration (validation phase) 35/100
# Finished in 10.705395698547363 (s)
# ------------------------------
# Iteration (validation phase) 36/100
# Finished in 16.193626880645752 (s)
# ------------------------------
# Iteration (validation phase) 37/100
# Finished in 11.069053888320923 (s)
# ------------------------------
# Iteration (validation phase) 38/100
# Finished in 14.63157057762146 (s)
# ------------------------------
# Iteration (validation phase) 39/100
# Finished in 12.834975004196167 (s)
# ------------------------------
# Iteration (validation phase) 40/100
# Finished in 12.616217374801636 (s)
# ------------------------------
# Iteration (validation phase) 41/100
# Finished in 14.90071988105774 (s)
# ------------------------------
# Iteration (validation phase) 42/100
# Finished in 10.880892038345337 (s)
# ------------------------------
# Iteration (validation phase) 43/100
# Finished in 16.577128887176514 (s)
# ------------------------------
# Iteration (validation phase) 44/100
# Finished in 10.354315042495728 (s)
# ------------------------------
# Iteration (validation phase) 45/100
# Finished in 14.978711128234863 (s)
# ------------------------------
# Iteration (validation phase) 46/100
# Finished in 12.215530395507812 (s)
# ------------------------------
# Iteration (validation phase) 47/100
# Finished in 13.111809968948364 (s)
# ------------------------------
# Iteration (validation phase) 48/100
# Finished in 14.508324146270752 (s)
# ------------------------------
# Iteration (validation phase) 49/100
# Finished in 11.05303144454956 (s)
# ------------------------------
# Iteration (validation phase) 50/100
# Finished in 16.59230637550354 (s)
# ------------------------------
# Iteration (validation phase) 51/100
# Finished in 10.48558497428894 (s)
# ------------------------------
# Iteration (validation phase) 52/100
# Finished in 15.047994375228882 (s)
# ------------------------------
# Iteration (validation phase) 53/100
# Finished in 12.61576247215271 (s)
# ------------------------------
# Iteration (validation phase) 54/100
# Finished in 12.975537538528442 (s)
# ------------------------------
# Iteration (validation phase) 55/100
# Finished in 14.600286722183228 (s)
# ------------------------------
# Iteration (validation phase) 56/100
# Finished in 10.972899198532104 (s)
# ------------------------------
# Iteration (validation phase) 57/100
# Finished in 16.348305463790894 (s)
# ------------------------------
# Iteration (validation phase) 58/100
# Finished in 10.362907648086548 (s)
# ------------------------------
# Iteration (validation phase) 59/100
# Finished in 15.080682277679443 (s)
# ------------------------------
# Iteration (validation phase) 60/100
# Finished in 12.356651544570923 (s)
# ------------------------------
# Iteration (validation phase) 61/100
# Finished in 13.237411260604858 (s)
# ------------------------------
# Iteration (validation phase) 62/100
# Finished in 14.592948198318481 (s)
# ------------------------------
# Iteration (validation phase) 63/100
# Finished in 11.208882808685303 (s)
# ------------------------------
# Iteration (validation phase) 64/100
# Finished in 16.378719806671143 (s)
# ------------------------------
# Iteration (validation phase) 65/100
# Finished in 10.390691995620728 (s)
# ------------------------------
# Iteration (validation phase) 66/100
# Finished in 14.891385555267334 (s)
# ------------------------------
# Iteration (validation phase) 67/100
# Finished in 12.769212245941162 (s)
# ------------------------------
# Iteration (validation phase) 68/100
# Finished in 12.99686050415039 (s)
# ------------------------------
# Iteration (validation phase) 69/100
# Finished in 14.910177230834961 (s)
# ------------------------------
# Iteration (validation phase) 70/100
# Finished in 11.06022024154663 (s)
# ------------------------------
# Iteration (validation phase) 71/100
# Finished in 16.5436749458313 (s)
# ------------------------------
# Iteration (validation phase) 72/100
# Finished in 10.633440732955933 (s)
# ------------------------------
# Iteration (validation phase) 73/100
# Finished in 23.066243171691895 (s)
# ------------------------------
# Iteration (validation phase) 74/100
# Finished in 14.076090335845947 (s)
# ------------------------------
# Iteration (validation phase) 75/100
# Finished in 12.458534002304077 (s)
# ------------------------------
# Iteration (validation phase) 76/100
# Finished in 15.752846002578735 (s)
# ------------------------------
# Iteration (validation phase) 77/100
# Finished in 10.50275993347168 (s)
# ------------------------------
# Iteration (validation phase) 78/100
# Finished in 16.220640420913696 (s)
# ------------------------------
# Iteration (validation phase) 79/100
# Finished in 11.143905401229858 (s)
# ------------------------------
# Iteration (validation phase) 80/100
# Finished in 14.290429592132568 (s)
# ------------------------------
# Iteration (validation phase) 81/100
# Finished in 13.356387853622437 (s)
# ------------------------------
# Iteration (validation phase) 82/100
# Finished in 12.108408689498901 (s)
# ------------------------------
# Iteration (validation phase) 83/100
# Finished in 15.482374906539917 (s)
# ------------------------------
# Iteration (validation phase) 84/100
# Finished in 10.543081521987915 (s)
# ------------------------------
# Iteration (validation phase) 85/100
# Finished in 16.305168390274048 (s)
# ------------------------------
# Iteration (validation phase) 86/100
# Finished in 10.877824783325195 (s)
# ------------------------------
# Iteration (validation phase) 87/100
# Finished in 14.443296909332275 (s)
# ------------------------------
# Iteration (validation phase) 88/100
# Finished in 12.865648031234741 (s)
# ------------------------------
# Iteration (validation phase) 89/100
# Finished in 12.563122510910034 (s)
# ------------------------------
# Iteration (validation phase) 90/100
# Finished in 15.887581825256348 (s)
# ------------------------------
# Iteration (validation phase) 91/100
# Finished in 10.580043077468872 (s)
# ------------------------------
# Iteration (validation phase) 92/100
# Finished in 16.489046096801758 (s)
# ------------------------------
# Iteration (validation phase) 93/100
# Finished in 11.667516231536865 (s)
# ------------------------------
# Iteration (validation phase) 94/100
# Finished in 14.351112365722656 (s)
# ------------------------------
# Iteration (validation phase) 95/100
# Finished in 13.827059507369995 (s)
# ------------------------------
# Iteration (validation phase) 96/100
# Finished in 11.999970197677612 (s)
# ------------------------------
# Iteration (validation phase) 97/100
# Finished in 16.337143421173096 (s)
# ------------------------------
# Iteration (validation phase) 98/100
# Finished in 10.348723888397217 (s)
# ------------------------------
# Iteration (validation phase) 99/100
# Finished in 15.98658561706543 (s)
# ------------------------------
# Iteration (validation phase) 100/100
# Finished in 11.86277961730957 (s)
# Epoch 1 - accuracy: 0.993
# ------------------------------------------------------------------------
# Finished epoch 1 in 6082.083446025848 (s).

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.993

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# <h2 id="Question_3">Question 3:Find the misclassified samples</h2>

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
validation_loader_batch_one = torch.utils.data.DataLoader(validation_dataset, batch_size=1, shuffle=False)

misclassified_samples = []
max_num_of_items = 4

model.eval()

with torch.no_grad():
    for i, (x_test, y_test) in enumerate(validation_loader_batch_one):
        x_test = x_test.to(device)
        y_test = y_test.to(device)

        yhat = model(x_test)
        _, predicted = torch.max(yhat.data, 1)

        if predicted != y_test:
            misclassified_samples.append((i, y_test.item(), predicted.item()))
            print(f"Sample: {i}; Expected Label: {y_test.item()}; Obtained Label: {predicted.item()}")
            if len(misclassified_samples) >= max_num_of_items:
                break
# Out:
# Sample: 132; Expected Label: 1; Obtained Label: 0
# Sample: 252; Expected Label: 1; Obtained Label: 0
# Sample: 320; Expected Label: 1; Obtained Label: 0
# Sample: 407; Expected Label: 0; Obtained Label: 1

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html?utm_source=Exinfluencer&utm_content=000026UJ&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01&utm_medium=Exinfluencer&utm_term=10006555"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-21  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
#
#
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# Copyright &copy; 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDL0321ENSkillsNetwork951-2022-01-01">MIT License</a>.
