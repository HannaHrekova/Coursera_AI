# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0321EN-SkillsNetwork/image/IDSN-logo.png" width="400"> </a>
#
# <h1 align=center><font size = 5>Pre-Trained Models</font></h1>

# %% [markdown]
# ## Objective

# %% [markdown]
# In this lab, you will learn how to leverage pre-trained models to build image classifiers instead of building a model from scratch.

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Import Libraries and Packages</a>
# 2. <a href="#item32">Download Data</a>
# 3. <a href="#item33">Define Global Constants</a>
# 4. <a href="#item34">Construct ImageDataGenerator Instances</a>
# 5. <a href="#item35">Compile and Fit Model</a>
#
# </font>
#
# </div>

# %% [markdown]
# <a id='item31'></a>

# %% [markdown]
# ## Import Libraries and Packages

# %% [markdown]
# Let's start the lab by importing the libraries that we will be using in this lab. First we will need the library that helps us to import the data.

# %% [markdown]
# First, we will import the ImageDataGenerator module since we will be leveraging it to train our model in batches.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# In this lab, we will be using the Keras library to build an image classifier, so let's download the Keras library.

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# Finally, we will be leveraging the ResNet50 model to build our classifier, so let's download it as well.

# %%
from keras.applications import ResNet50
from keras.applications.resnet50 import preprocess_input

# %% [markdown]
# <a id='item32'></a>

# %% [markdown]
# ## Download Data

# %% [markdown]
# In this section, you are going to download the data from IBM object storage using **skillsnetwork.prepare** command. skillsnetwork.prepare is a command that's used to download a zip file, unzip it and store it in a specified directory.

# %%
## get the data
# !unzip concrete_data_week3.zip -d /content/data/
# !ls /content/data/
# Out:
# Показано результат, скорочений до останніх рядків (5000).
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00196.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02959.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02959.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02781.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02781.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04496.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04496.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00828.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00828.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00800.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00800.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02971.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02971.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02965.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02965.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00814.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00814.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04441.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04441.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02030.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02030.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01539.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01539.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00627.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00627.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00141.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00141.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02756.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02756.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03448.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03448.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04327.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04327.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02742.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02742.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04333.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04333.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00155.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00155.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00633.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00633.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04455.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04455.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02024.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02024.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01505.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01505.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03312.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03312.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03474.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03474.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01263.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01263.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00169.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00169.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01277.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01277.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03460.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03460.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04469.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04469.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03306.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03306.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02018.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02018.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01511.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01511.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00616.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00616.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01508.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01508.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02001.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02001.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04470.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04470.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03479.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03479.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04316.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04316.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02767.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02767.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00170.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00170.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00164.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00164.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04302.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04302.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02773.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02773.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02015.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02015.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04464.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04464.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00602.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00602.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03323.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03323.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01534.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01534.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01252.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01252.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03445.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03445.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02983.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02983.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03451.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03451.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02997.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02997.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01246.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01246.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00158.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00158.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01520.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01520.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02029.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02029.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04458.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04458.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03337.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03337.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02968.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02968.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00819.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00819.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00831.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00831.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02798.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02798.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03486.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03486.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02940.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02940.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01291.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01291.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01285.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01285.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03492.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03492.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02954.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02954.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00825.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00825.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00372.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00372.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02565.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02565.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04114.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04114.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04672.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04672.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02203.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02203.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00414.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00414.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00400.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00400.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03109.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03109.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04666.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04666.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02217.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02217.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02571.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02571.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04100.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04100.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00366.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00366.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01078.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01078.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02559.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02559.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04128.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04128.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03647.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03647.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01050.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01050.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01736.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01736.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00428.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00428.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03121.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03121.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04896.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04896.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03135.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03135.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04882.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04882.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01722.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01722.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01044.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01044.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03653.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03653.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03860.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03860.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01911.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01911.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04869.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04869.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01905.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01905.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03874.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03874.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01093.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01093.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03684.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03684.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04855.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04855.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01939.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01939.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04841.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04841.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04699.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04699.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03690.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03690.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03848.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03848.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01087.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01087.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00399.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00399.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01118.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01118.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00206.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00206.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04060.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04060.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02411.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02411.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02377.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02377.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04706.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04706.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03069.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03069.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00560.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00560.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00574.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00574.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02363.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02363.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04712.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04712.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04074.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04074.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02405.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02405.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00212.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00212.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03733.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03733.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01124.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01124.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01642.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01642.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03055.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03055.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03041.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03041.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00548.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00548.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01656.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01656.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01130.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01130.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03727.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03727.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04048.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04048.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02439.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02439.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03914.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03914.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01865.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01865.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04909.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04909.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01871.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01871.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03900.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03900.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03928.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03928.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03096.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03096.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02388.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02388.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04921.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04921.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01681.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01681.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01859.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01859.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01695.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01695.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03082.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03082.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04935.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04935.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00762.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00762.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04504.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04504.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02175.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02175.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02613.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02613.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04262.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04262.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00004.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00004.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00010.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00010.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02607.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02607.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04276.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04276.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03519.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03519.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04510.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04510.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02161.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02161.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01468.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01468.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00776.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00776.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03257.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03257.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04538.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04538.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02149.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02149.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01440.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01440.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00986.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00986.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00038.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00038.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01326.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01326.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03531.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03531.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03525.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03525.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01332.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01332.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01454.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01454.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00992.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00992.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03243.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03243.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00979.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00979.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02808.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02808.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01483.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01483.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00945.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00945.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03294.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03294.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02834.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02834.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04289.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04289.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02820.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02820.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03280.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03280.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00789.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00789.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01497.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01497.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00951.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00951.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02821.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02821.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04288.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04288.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00950.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00950.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01496.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01496.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00788.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00788.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03281.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03281.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03295.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03295.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00944.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00944.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01482.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01482.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02835.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02835.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00978.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00978.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02809.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02809.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01333.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01333.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03524.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03524.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03242.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03242.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00993.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00993.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01455.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01455.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00987.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00987.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01441.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01441.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02148.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02148.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04539.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04539.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03256.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03256.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03530.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03530.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01327.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01327.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00039.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00039.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03518.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03518.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04277.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04277.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02606.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02606.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00011.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00011.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00777.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00777.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01469.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01469.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02160.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02160.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04511.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04511.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02174.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02174.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04505.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04505.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00763.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00763.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00005.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00005.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04263.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04263.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02612.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02612.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04934.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04934.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03083.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03083.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01694.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01694.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03929.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03929.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01858.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01858.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01680.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01680.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04920.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04920.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02389.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02389.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03097.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03097.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01870.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01870.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04908.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04908.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03901.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03901.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03915.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03915.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01864.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01864.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01657.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01657.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00549.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00549.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03040.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03040.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02438.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02438.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04049.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04049.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03726.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03726.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01131.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01131.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01125.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01125.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03732.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03732.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03054.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03054.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01643.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01643.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04713.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04713.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02362.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02362.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00575.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00575.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00213.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00213.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02404.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02404.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04075.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04075.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02410.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02410.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04061.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04061.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00207.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00207.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01119.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01119.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00561.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00561.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03068.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03068.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04707.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04707.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02376.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02376.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04698.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04698.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04840.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04840.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01938.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01938.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00398.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00398.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01086.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01086.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03849.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03849.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03691.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03691.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03685.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03685.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01092.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01092.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04854.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04854.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01904.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01904.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03875.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03875.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03861.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03861.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04868.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04868.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01910.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01910.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01723.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01723.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04883.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04883.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03134.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03134.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03652.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03652.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01045.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01045.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01051.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01051.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03646.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03646.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04129.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04129.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02558.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02558.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04897.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04897.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03120.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03120.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00429.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00429.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01737.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01737.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02216.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02216.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04667.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04667.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03108.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03108.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00401.jpg
# ...
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04013.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00275.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00275.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00261.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00261.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02476.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02476.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03768.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03768.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04007.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04007.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04761.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04761.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02310.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02310.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01619.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01619.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00507.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00507.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04749.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04749.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03026.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03026.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02338.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02338.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04991.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04991.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01631.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01631.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00249.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00249.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01157.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01157.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03998.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03998.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03740.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03740.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03754.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03754.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01143.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01143.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01625.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01625.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03032.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03032.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04985.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04985.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01962.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01962.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03813.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03813.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03807.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03807.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01976.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01976.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01786.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01786.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00498.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00498.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03191.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03191.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04826.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04826.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04198.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04198.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03185.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03185.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04832.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04832.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01792.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01792.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00467.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00467.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01779.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01779.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02270.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02270.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04601.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04601.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04167.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04167.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03608.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03608.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02516.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02516.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00301.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00301.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00315.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00315.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04173.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04173.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02502.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02502.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02264.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02264.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04615.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04615.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00473.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00473.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03152.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03152.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01745.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01745.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01023.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01023.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03634.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03634.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03620.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03620.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01037.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01037.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00329.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00329.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01989.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01989.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01751.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01751.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02258.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02258.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03146.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03146.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04629.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04629.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02933.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02933.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03393.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03393.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00842.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00842.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01584.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01584.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00856.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00856.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01590.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01590.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02099.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02099.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03387.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03387.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02927.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02927.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00103.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00103.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02714.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02714.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04365.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04365.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04403.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04403.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02072.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02072.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00665.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00665.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00671.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00671.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04417.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04417.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03378.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03378.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02066.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02066.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02700.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02700.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04371.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04371.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00117.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00117.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01209.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01209.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/02728.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._02728.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03436.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03436.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/04359.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._04359.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01221.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01221.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00881.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00881.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01547.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01547.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00659.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00659.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03350.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03350.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03344.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03344.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/00895.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._00895.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01553.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01553.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/01235.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._01235.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/03422.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/._03422.jpg
#   inflating: /content/data/concrete_data_week3/valid/negative/.ipynb_checkpoints/00002-checkpoint.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/valid/negative/.ipynb_checkpoints/._00002-checkpoint.jpg
#   inflating: /content/data/concrete_data_week3/train/negative/.ipynb_checkpoints/00002-checkpoint.jpg
#   inflating: /content/data/__MACOSX/concrete_data_week3/train/negative/.ipynb_checkpoints/._00002-checkpoint.jpg
# concrete_data_week3  __MACOSX

# %% [markdown]
# Now, you should see the folder *concrete_data_week3* appear in the left pane. If you open this folder by double-clicking on it, you will find that it contains two folders: *train* and *valid*. And if you explore these folders, you will find that each contains two subfolders: *positive* and *negative*. These are the same folders that we saw in the labs in the previous modules of this course, where *negative* is the negative class and it represents the concrete images with no cracks and *positive* is the positive class and it represents the concrete images with cracks.

# %% [markdown]
# **Important Note**: There are thousands and thousands of images in each folder, so please don't attempt to double click on the *negative* and *positive* folders. This may consume all of your memory and you may end up with a **50** error. So please **DO NOT DO IT**.

# %% [markdown]
# <a id='item33'></a>

# %% [markdown]
# ## Define Global Constants

# %% [markdown]
# Here, we will define constants that we will be using throughout the rest of the lab.
#
# 1. We are obviously dealing with two classes, so *num_classes* is 2.
# 2. The ResNet50 model was built and trained using images of size (224 x 224). Therefore, we will have to resize our images from (227 x 227) to (224 x 224).
# 3. We will training and validating the model using batches of 100 images.

# %%
num_classes = 2

image_resize = 224

batch_size_training = 100
batch_size_validation = 100

# %% [markdown]
# <a id='item34'></a>

# %% [markdown]
# ## Construct ImageDataGenerator Instances

# %% [markdown]
# In order to instantiate an ImageDataGenerator instance, we will set the **preprocessing_function** argument to *preprocess_input* which we imported from **keras.applications.resnet50** in order to preprocess our images the same way the images used to train ResNet50 model were processed.

# %%
data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %% [markdown]
# Next, we will use the *flow_from_directory* method to get the training images as follows:

# %%
train_generator = data_generator.flow_from_directory(
    '/content/data/concrete_data_week3/train',
    target_size=(image_resize, image_resize),
    batch_size=batch_size_training,
    class_mode='categorical')
# Out:
# Found 10001 images belonging to 2 classes.

# %% [markdown]
# **Note**: in this lab, we will be using the full data-set of 30,000 images for training and validation.

# %% [markdown]
# **Your Turn**: Use the *flow_from_directory* method to get the validation images and assign the result to **validation_generator**.

# %%
validation_generator = data_generator.flow_from_directory(
    '/content/data/concrete_data_week3/valid',
    target_size=(image_resize, image_resize),
    batch_size=batch_size_validation,
    class_mode='categorical')
# Out:
# Found 5001 images belonging to 2 classes.

# %% [markdown]
# Double-click __here__ for the solution.
# <!-- The correct answer is:
# validation_generator = data_generator.flow_from_directory(
#     'concrete_data_week3/valid',
#     target_size=(image_resize, image_resize),
#     batch_size=batch_size_validation,
#     class_mode='categorical')
# -->

# %% [markdown]
# <a id='item35'></a>

# %% [markdown]
# ## Build, Compile and Fit Model

# %% [markdown]
# In this section, we will start building our model. We will use the Sequential model class from Keras.

# %%
model = Sequential()

# %% [markdown]
# Next, we will add the ResNet50 pre-trained model to out model. However, note that we don't want to include the top layer or the output layer of the pre-trained model. We actually want to define our own output layer and train it so that it is optimized for our image dataset. In order to leave out the output layer of the pre-trained model, we will use the argument *include_top* and set it to **False**.

# %%
model.add(ResNet50(
    include_top=False,
    pooling='avg',
    weights='imagenet',
    ))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %% [markdown]
# Then, we will define our output layer as a **Dense** layer, that consists of two nodes and uses the **Softmax** function as the activation function.

# %%
model.add(Dense(num_classes, activation='softmax'))

# %% [markdown]
# You can access the model's layers using the *layers* attribute of our model object.

# %%
model.layers
# Out:
# [<Functional name=resnet50, built=True>, <Dense name=dense, built=True>]

# %% [markdown]
# You can see that our model is composed of two sets of layers. The first set is the layers pertaining to ResNet50 and the second set is a single layer, which is our Dense layer that we defined above.

# %% [markdown]
# You can access the ResNet50 layers by running the following:

# %%
model.layers[0].layers
# Out:
# [<InputLayer name=input_layer, built=True>,
#  <ZeroPadding2D name=conv1_pad, built=True>,
#  <Conv2D name=conv1_conv, built=True>,
#  <BatchNormalization name=conv1_bn, built=True>,
#  <Activation name=conv1_relu, built=True>,
#  <ZeroPadding2D name=pool1_pad, built=True>,
#  <MaxPooling2D name=pool1_pool, built=True>,
#  <Conv2D name=conv2_block1_1_conv, built=True>,
#  <BatchNormalization name=conv2_block1_1_bn, built=True>,
#  <Activation name=conv2_block1_1_relu, built=True>,
#  <Conv2D name=conv2_block1_2_conv, built=True>,
#  <BatchNormalization name=conv2_block1_2_bn, built=True>,
#  <Activation name=conv2_block1_2_relu, built=True>,
#  <Conv2D name=conv2_block1_0_conv, built=True>,
#  <Conv2D name=conv2_block1_3_conv, built=True>,
#  <BatchNormalization name=conv2_block1_0_bn, built=True>,
#  <BatchNormalization name=conv2_block1_3_bn, built=True>,
#  <Add name=conv2_block1_add, built=True>,
#  <Activation name=conv2_block1_out, built=True>,
#  <Conv2D name=conv2_block2_1_conv, built=True>,
#  <BatchNormalization name=conv2_block2_1_bn, built=True>,
#  <Activation name=conv2_block2_1_relu, built=True>,
#  <Conv2D name=conv2_block2_2_conv, built=True>,
#  <BatchNormalization name=conv2_block2_2_bn, built=True>,
#  <Activation name=conv2_block2_2_relu, built=True>,
#  <Conv2D name=conv2_block2_3_conv, built=True>,
#  <BatchNormalization name=conv2_block2_3_bn, built=True>,
#  <Add name=conv2_block2_add, built=True>,
#  <Activation name=conv2_block2_out, built=True>,
#  <Conv2D name=conv2_block3_1_conv, built=True>,
#  <BatchNormalization name=conv2_block3_1_bn, built=True>,
#  <Activation name=conv2_block3_1_relu, built=True>,
#  <Conv2D name=conv2_block3_2_conv, built=True>,
#  <BatchNormalization name=conv2_block3_2_bn, built=True>,
#  <Activation name=conv2_block3_2_relu, built=True>,
#  <Conv2D name=conv2_block3_3_conv, built=True>,
#  <BatchNormalization name=conv2_block3_3_bn, built=True>,
#  <Add name=conv2_block3_add, built=True>,
#  <Activation name=conv2_block3_out, built=True>,
#  <Conv2D name=conv3_block1_1_conv, built=True>,
#  <BatchNormalization name=conv3_block1_1_bn, built=True>,
#  <Activation name=conv3_block1_1_relu, built=True>,
#  <Conv2D name=conv3_block1_2_conv, built=True>,
#  <BatchNormalization name=conv3_block1_2_bn, built=True>,
#  <Activation name=conv3_block1_2_relu, built=True>,
#  <Conv2D name=conv3_block1_0_conv, built=True>,
#  <Conv2D name=conv3_block1_3_conv, built=True>,
#  <BatchNormalization name=conv3_block1_0_bn, built=True>,
#  <BatchNormalization name=conv3_block1_3_bn, built=True>,
#  <Add name=conv3_block1_add, built=True>,
#  <Activation name=conv3_block1_out, built=True>,
#  <Conv2D name=conv3_block2_1_conv, built=True>,
#  <BatchNormalization name=conv3_block2_1_bn, built=True>,
#  <Activation name=conv3_block2_1_relu, built=True>,
#  <Conv2D name=conv3_block2_2_conv, built=True>,
#  <BatchNormalization name=conv3_block2_2_bn, built=True>,
#  <Activation name=conv3_block2_2_relu, built=True>,
#  <Conv2D name=conv3_block2_3_conv, built=True>,
#  <BatchNormalization name=conv3_block2_3_bn, built=True>,
#  <Add name=conv3_block2_add, built=True>,
#  <Activation name=conv3_block2_out, built=True>,
#  <Conv2D name=conv3_block3_1_conv, built=True>,
#  <BatchNormalization name=conv3_block3_1_bn, built=True>,
#  <Activation name=conv3_block3_1_relu, built=True>,
#  <Conv2D name=conv3_block3_2_conv, built=True>,
#  <BatchNormalization name=conv3_block3_2_bn, built=True>,
#  <Activation name=conv3_block3_2_relu, built=True>,
#  <Conv2D name=conv3_block3_3_conv, built=True>,
#  <BatchNormalization name=conv3_block3_3_bn, built=True>,
#  <Add name=conv3_block3_add, built=True>,
#  <Activation name=conv3_block3_out, built=True>,
#  <Conv2D name=conv3_block4_1_conv, built=True>,
#  <BatchNormalization name=conv3_block4_1_bn, built=True>,
#  <Activation name=conv3_block4_1_relu, built=True>,
#  <Conv2D name=conv3_block4_2_conv, built=True>,
#  <BatchNormalization name=conv3_block4_2_bn, built=True>,
#  <Activation name=conv3_block4_2_relu, built=True>,
#  <Conv2D name=conv3_block4_3_conv, built=True>,
#  <BatchNormalization name=conv3_block4_3_bn, built=True>,
#  <Add name=conv3_block4_add, built=True>,
#  <Activation name=conv3_block4_out, built=True>,
#  <Conv2D name=conv4_block1_1_conv, built=True>,
#  <BatchNormalization name=conv4_block1_1_bn, built=True>,
#  <Activation name=conv4_block1_1_relu, built=True>,
#  <Conv2D name=conv4_block1_2_conv, built=True>,
#  <BatchNormalization name=conv4_block1_2_bn, built=True>,
#  <Activation name=conv4_block1_2_relu, built=True>,
#  <Conv2D name=conv4_block1_0_conv, built=True>,
#  <Conv2D name=conv4_block1_3_conv, built=True>,
#  <BatchNormalization name=conv4_block1_0_bn, built=True>,
#  <BatchNormalization name=conv4_block1_3_bn, built=True>,
#  <Add name=conv4_block1_add, built=True>,
#  <Activation name=conv4_block1_out, built=True>,
#  <Conv2D name=conv4_block2_1_conv, built=True>,
#  <BatchNormalization name=conv4_block2_1_bn, built=True>,
#  <Activation name=conv4_block2_1_relu, built=True>,
#  <Conv2D name=conv4_block2_2_conv, built=True>,
#  <BatchNormalization name=conv4_block2_2_bn, built=True>,
#  <Activation name=conv4_block2_2_relu, built=True>,
#  <Conv2D name=conv4_block2_3_conv, built=True>,
#  <BatchNormalization name=conv4_block2_3_bn, built=True>,
#  <Add name=conv4_block2_add, built=True>,
#  <Activation name=conv4_block2_out, built=True>,
#  <Conv2D name=conv4_block3_1_conv, built=True>,
#  <BatchNormalization name=conv4_block3_1_bn, built=True>,
#  <Activation name=conv4_block3_1_relu, built=True>,
#  <Conv2D name=conv4_block3_2_conv, built=True>,
#  <BatchNormalization name=conv4_block3_2_bn, built=True>,
#  <Activation name=conv4_block3_2_relu, built=True>,
#  <Conv2D name=conv4_block3_3_conv, built=True>,
#  <BatchNormalization name=conv4_block3_3_bn, built=True>,
#  <Add name=conv4_block3_add, built=True>,
#  <Activation name=conv4_block3_out, built=True>,
#  <Conv2D name=conv4_block4_1_conv, built=True>,
#  <BatchNormalization name=conv4_block4_1_bn, built=True>,
#  <Activation name=conv4_block4_1_relu, built=True>,
#  <Conv2D name=conv4_block4_2_conv, built=True>,
#  <BatchNormalization name=conv4_block4_2_bn, built=True>,
#  <Activation name=conv4_block4_2_relu, built=True>,
#  <Conv2D name=conv4_block4_3_conv, built=True>,
#  <BatchNormalization name=conv4_block4_3_bn, built=True>,
#  <Add name=conv4_block4_add, built=True>,
#  <Activation name=conv4_block4_out, built=True>,
#  <Conv2D name=conv4_block5_1_conv, built=True>,
#  <BatchNormalization name=conv4_block5_1_bn, built=True>,
#  <Activation name=conv4_block5_1_relu, built=True>,
#  <Conv2D name=conv4_block5_2_conv, built=True>,
#  <BatchNormalization name=conv4_block5_2_bn, built=True>,
#  <Activation name=conv4_block5_2_relu, built=True>,
#  <Conv2D name=conv4_block5_3_conv, built=True>,
#  <BatchNormalization name=conv4_block5_3_bn, built=True>,
#  <Add name=conv4_block5_add, built=True>,
#  <Activation name=conv4_block5_out, built=True>,
#  <Conv2D name=conv4_block6_1_conv, built=True>,
#  <BatchNormalization name=conv4_block6_1_bn, built=True>,
#  <Activation name=conv4_block6_1_relu, built=True>,
#  <Conv2D name=conv4_block6_2_conv, built=True>,
#  <BatchNormalization name=conv4_block6_2_bn, built=True>,
#  <Activation name=conv4_block6_2_relu, built=True>,
#  <Conv2D name=conv4_block6_3_conv, built=True>,
#  <BatchNormalization name=conv4_block6_3_bn, built=True>,
#  <Add name=conv4_block6_add, built=True>,
#  <Activation name=conv4_block6_out, built=True>,
#  <Conv2D name=conv5_block1_1_conv, built=True>,
#  <BatchNormalization name=conv5_block1_1_bn, built=True>,
#  <Activation name=conv5_block1_1_relu, built=True>,
#  <Conv2D name=conv5_block1_2_conv, built=True>,
#  <BatchNormalization name=conv5_block1_2_bn, built=True>,
#  <Activation name=conv5_block1_2_relu, built=True>,
#  <Conv2D name=conv5_block1_0_conv, built=True>,
#  <Conv2D name=conv5_block1_3_conv, built=True>,
#  <BatchNormalization name=conv5_block1_0_bn, built=True>,
#  <BatchNormalization name=conv5_block1_3_bn, built=True>,
#  <Add name=conv5_block1_add, built=True>,
#  <Activation name=conv5_block1_out, built=True>,
#  <Conv2D name=conv5_block2_1_conv, built=True>,
#  <BatchNormalization name=conv5_block2_1_bn, built=True>,
#  <Activation name=conv5_block2_1_relu, built=True>,
#  <Conv2D name=conv5_block2_2_conv, built=True>,
#  <BatchNormalization name=conv5_block2_2_bn, built=True>,
#  <Activation name=conv5_block2_2_relu, built=True>,
#  <Conv2D name=conv5_block2_3_conv, built=True>,
#  <BatchNormalization name=conv5_block2_3_bn, built=True>,
#  <Add name=conv5_block2_add, built=True>,
#  <Activation name=conv5_block2_out, built=True>,
#  <Conv2D name=conv5_block3_1_conv, built=True>,
#  <BatchNormalization name=conv5_block3_1_bn, built=True>,
#  <Activation name=conv5_block3_1_relu, built=True>,
#  <Conv2D name=conv5_block3_2_conv, built=True>,
#  <BatchNormalization name=conv5_block3_2_bn, built=True>,
#  <Activation name=conv5_block3_2_relu, built=True>,
#  <Conv2D name=conv5_block3_3_conv, built=True>,
#  <BatchNormalization name=conv5_block3_3_bn, built=True>,
#  <Add name=conv5_block3_add, built=True>,
#  <Activation name=conv5_block3_out, built=True>,
#  <GlobalAveragePooling2D name=avg_pool, built=True>]

# %% [markdown]
# Since the ResNet50 model has already been trained, then we want to tell our model not to bother with training the ResNet part, but to train only our dense output layer. To do that, we run the following.

# %%
model.layers[0].trainable = False

# %% [markdown]
# And now using the *summary* attribute of the model, we can see how many parameters we will need to optimize in order to train the output layer.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)                │ (None, 2048)                │      23,587,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 2)                   │           4,098 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 23,591,810 (90.00 MB)
#  Trainable params: 4,098 (16.01 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %% [markdown]
# Next we compile our model using the **adam** optimizer.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Before we are able to start the training process, with an ImageDataGenerator, we will need to define how many steps compose an epoch. Typically, that is the number of images divided by the batch size. Therefore, we define our steps per epoch as follows:

# %%
steps_per_epoch_training = len(train_generator)
steps_per_epoch_validation = len(validation_generator)
num_epochs = 2

# %% [markdown]
# Finally, we are ready to start training our model. Unlike a conventional deep learning training were data is not streamed from a directory, with an ImageDataGenerator where data is augmented in batches, we use the **fit_generator** method.

# %%
fit_history = model.fit(
    train_generator,
    steps_per_epoch=steps_per_epoch_training,
    epochs=num_epochs,
    validation_data=validation_generator,
    validation_steps=steps_per_epoch_validation,
    verbose=1,
)
# Out:
# Epoch 1/2
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 69s 518ms/step - accuracy: 0.9059 - loss: 0.2058 - val_accuracy: 0.9966 - val_loss: 0.0168
# Epoch 2/2
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - accuracy: 0.0000e+00 - loss: 0.0000e+00
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)

# %% [markdown]
# Now that the model is trained, you are ready to start using it to classify images.

# %% [markdown]
# Since training can take a long time when building deep learning models, it is always a good idea to save your model once the training is complete if you believe you will be using the model again later. You will be using this model in the next module, so go ahead and save your model.

# %%
model.save('classifier_resnet_model.keras')

# %% [markdown]
# Now, you should see the model file *classifier_resnet_model.h5* apprear in the left directory pane.

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by Alex Aklson. I hope you found this lab interesting and educational.

# %% [markdown]
# This notebook is part of a course on **Coursera** called *AI Capstone Project with Deep Learning*. If you accessed this notebook outside the course, you can take this course online by clicking [here](https://cocl.us/DL0321EN_Coursera_Week3_LAB1).

# %% [markdown]
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-09-18  | 2.0  | Shubham  |  Migrated Lab to Markdown and added to course repo in GitLab |
# | 2023-01-03  | 3.0  | Artem |  Updated the file import section|

# %% [markdown]
# <hr>
#
# Copyright &copy; 2020 [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
