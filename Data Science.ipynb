# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Hanna**
# AI Specialist

# %% [markdown]
# *I am interested in data science as I dream of becoming an AI specialist.*

# %% [markdown]
# ### Five and three is my favourite numbers. So, let it be five plus three

# %%
5+3
# Out:
# 8

# %% [markdown]
# Bulleted list
# - One
# - Two
# - Three
#
# Numbered list
# 1. First
# 2. Second
# 3. Third
#
# Tables
# | Column 1 | Column 2 |
# |-----------|-----------|
# | Line 1    | Value 1 |
# | Line 2    | Value 2 |
#
# Hyperlink
# [OpenAI](https://www.openai.com)
